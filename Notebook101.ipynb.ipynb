# %%
345 + 879
# Out:
# 1224

# %%
79*89
# Out:
# 7031

# %% [markdown]
# # First Title

# %% [markdown]
# # This is a text which cannot be run

# %% [markdown]
# ## Second Title

# %% [markdown]
# ### Third Title

# %%
3**4
# Out:
# 81

# %% [markdown]
#  <a href=https://www.cognitiveclass.ai>Cognitive Class</a>
